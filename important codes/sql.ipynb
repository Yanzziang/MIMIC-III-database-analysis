# %%
# %env DATABASE_URL=postgresql://mimicuser:TokyoP@rkDrpgolf@localhost/mimic

# %%
# %env DATABASE_URL=postgresql://mimicuser:TokyoP%40rkDr!pgolf@localhost/mimic
# Out:
# env: DATABASE_URL=postgresql://mimicuser:TokyoP%40rkDr!pgolf@localhost/mimic

# %%
import os
import psycopg2
import pandas as pd
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)
def get_connection():
    dsn = os.environ.get('DATABASE_URL')
    return psycopg2.connect(dsn)
# Out:
# /home/yzza/.local/lib/python3.5/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
conn = get_connection()

# %%
# df = pd.read_sql(sql="select * from mimiciii.cptevents where cpt_cd ~ '^[0-9]*$';", con=conn)
# df
# ana = df.loc[df['cpt_cd'].astype(int).between(99143, 99150)]
# ana.to_csv('use_sedation_cptcd.csv')

# %%
# df = pd.read_sql(sql="select distinct drug_name_generic as drug_name_generic_n from mimiciii.prescriptions;", con=conn)
# df.to_csv('all_drug_name_generic.csv')

# %%
# df = pd.read_sql(sql="select subject_id, count(distinct Drug) \
#                       as drug_number from mimiciii.prescriptions group by subject_id limit 10;", con=conn)’‘’

# %%
# contain_n = 'Morphine2' 
# df = pd.read_sql(sql="select * from mimiciii.prescriptions where drug like '%Morphine%';", con=conn)
# df.to_csv(contain_n + '.csv')

# %%
# df = pd.read_sql(sql="select count(row_id) as row_num from mimiciii.prescriptions;", con=conn)
# df

# %%
df = pd.read_sql(sql="select distinct drug from mimiciii.prescriptions where drug like '%Morphine%';", con=conn)
df

# %%
df = pd.read_sql(sql="select distinct subject_id, icustay_id from mimiciii.prescriptions where drug like '%Morphine%';", con=conn)
df.to_csv('abusolute subject id using morphine.csv')

# %%
import numpy as np
import pandas as pd
s = pd.read_sql(sql="select * from mimiciii.admissions;", con=conn)

# %%
k = s['diagnosis'].value_counts().tolist()
m = k[10:]
mmm = 0
for iii in m:
    mmm += iii
mmm
# Out:
# 43138

# %%
import numpy as np
import pandas as pd
s = pd.read_sql(sql="select * from mimiciii.d_items;", con=conn)

# %%
s[:400]
# Out:
#      row_id  itemid                                        label abbreviation  \
# 0    457     497     Patient controlled analgesia (PCA) [Inject]  None
# 1    458     498     PCA Lockout (Min)                            None
# 2    459     499     PCA Medication                               None
# 3    460     500     PCA Total Dose                               None
# 4    461     501     PCV Exh Vt (Obser)                           None
# 5    1157    927     Allergy 2                                    None
# 6    1158    930     Ext                                          None
# 7    1159    935     Allergy 3                                    None
# 8    1160    938     blood cultures                               None
# 9    1161    940     trach care                                   None
# 10   1162    941     urine culture                                None
# 11   1163    942     BLOOD CULTURES                               None
# ...

# %%
s = s['diagnosis'].value_counts()[:10]

# %%
s.to_csv('./presentation/diagonsis_numbers.csv')

# %%
sepsis_code = pd.read_sql(sql="select * from mimiciii.d_icd_diagnoses where short_title like '%sepsis%' or short_title like '%Sepsis%';", con=conn)

# %%
sepsis_code

# %%
sepsis = pd.read_sql(sql="select * from mimiciii.diagnoses_icd where icd9_code like '99591' or icd9_code like '99592';", con=conn)

# %%
sepsis[:10]

# %%
##pne = pd.read_sql(sql="select * from mimiciii.d_icd_diagnoses where short_title like '%pneumonia%' or short_title like '%pneumonia%';", con=conn)

# %%
##pne

# %%
import numpy as np
import pandas as pd
sk= pd.read_sql(sql="select * from mimiciii.d_labitems where itemid = '50825';", con=conn)

# %%
sk.head()

# %%
import numpy as np
import pandas as pd
sk= pd.read_sql(sql="select diagnose from mimiciii.admissions;", con=conn)

# %%
1*2

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-73b8acb9a6aa> in <module>()
# ----> 1 sk[:3]
#
# NameError: name 'sk' is not defined

# %%
import numpy as np
import pandas as pd
d_labitem = pd.read_sql(sql="select * from mimiciii.outputevents;", con=conn)

# %%
d_labitem.count()
# Out:
# row_id        4349218
# subject_id    4349218
# hadm_id       4344379
# icustay_id    4342028
# charttime     4349218
# itemid        4349218
# value         4260669
# valueuom      4312967
# storetime     4349218
# cgid          4349218
# stopped       0
# newbottle     0
# iserror       0
# dtype: int64

# %%
d_labitem = pd.read_sql(sql="select * from mimiciii.outputevents;", con=conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# ProgrammingError: syntax error at or near "50"
# LINE 1: select top 50 percent * from mimiciii.outputevents;
#                    ^
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-39-f7b53798c622> in <module>()
# ----> 1 d_labitem = pd.read_sql(sql="select top 50 percent * from mimiciii.outputevents;", con=conn)
#
# ~/.local/lib/python3.5/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
# ...
